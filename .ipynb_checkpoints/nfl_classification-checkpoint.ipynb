# %% [markdown]
# # NFL 2020 Forecasting Yards Gained
#
# > “The running back takes the handoff… he breaks a tackle…spins… and breaks free! One man to beat! Past the 50-yard-line! To the 40! The 30! He! Could! Go! All! The! Way!”
#
# But will he?
#
# American football is a complex sport. From the 22 players on the field to specific characteristics that ebb and flow throughout the game, it can be challenging to quantify the value of specific plays and actions within a play. Fundamentally, the goal of football is for the offense to run (rush) or throw (pass) the ball to gain yards, moving towards, then across, the opposing team’s side of the field in order to score. And the goal of the defense is to prevent the offensive team from scoring.
#
# In the National Football League (NFL), roughly a third of teams’ offensive yardage comes from run plays. Ball carriers are generally assigned the most credit for these plays, but their teammates (by way of blocking), coach (by way of play call), and the opposing defense also play a critical role. Traditional metrics such as ‘yards per carry’ or ‘total rushing yards’ can be flawed; in this competition, the NFL aims to provide better context into what contributes to a successful run play.
#
# As an “armchair quarterback” watching the game, you may think you can predict the result of a play when a ball carrier takes the handoff - but what does the data say? Deeper insight into rushing plays will help teams, media, and fans better understand the skill of players and the strategies of coaches. It will also assist the NFL and its teams evaluate the ball carrier, his teammates, his coach, and the opposing defense, in order to make adjustments as necessary.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from modeling import *
from visualizations import *
import catboost as cb
import pickle
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data Preprocessing

# %%
cols = list(pd.read_csv('Data/cleaned_nfl.csv', nrows=1))
nfl = pd.read_csv('Data/cleaned_nfl.csv',
                  usecols =[i for i in cols if i != 'Yards'])
nfl
# Out:
#         Team  long_axis  short_axis  speed  accel   Dis  Orientation     Dir  \
# 0       away      73.91       34.84   1.69   1.13  0.40        81.99  177.18
# 1       away      74.67       32.64   0.42   1.35  0.01        27.61  198.70
# 2       away      74.00       33.20   1.22   0.59  0.31         3.01  202.73
# 3       away      71.46       27.70   0.42   0.54  0.02       359.77  105.64
# 4       away      69.32       35.42   1.82   2.43  0.16        12.63  164.31
# 5       away      75.06       24.00   1.01   0.32  0.18       308.34   95.01
# 6       away      74.11       16.64   1.11   0.83  0.02       357.23  322.59
# 7       away      73.37       18.73   1.24   0.74  0.13       328.52  270.04
# 8       away      56.63       26.90   0.26   1.86  0.28       344.70   55.31
# 9       away      73.35       38.83   4.55   0.76  0.51        75.47  190.84
# 10      away      74.15       28.90   0.72   0.73  0.01       342.58  274.14
# 11      home      75.82       17.56   2.30   1.39  0.55       178.97  284.15
# 12      home      74.78       33.21   1.71   0.82  0.19       178.82  215.90
# 13      home      75.43       32.41   1.50   1.36  0.32       207.08  222.76
# 14      home      75.90       25.12   1.38   0.80  0.19       133.01  198.55
# 15      home      79.76       29.49   0.84   1.22  0.00       192.18  110.86
# 16      home      76.47       36.91   5.15   0.77  0.59       112.02  195.09
# 17      home      74.70       19.19   2.10   1.48  0.51       152.14  278.52
# 18      home      78.75       30.53   3.63   3.35  0.38       161.98  245.74
# 19      home      74.60       31.88   1.86   1.51  0.17       218.49  267.32
# 20      home      74.58       29.12   1.00   0.69  0.22       169.36  242.05
# 21      home      74.58       28.47   1.70   1.55  0.24       207.09  255.67
# 22      away      65.73       33.88   1.53   2.16  0.20        70.30  165.70
# 23      away      66.04       30.09   1.20   1.06  0.01       354.01  254.78
# 24      away      66.02       31.50   0.73   0.84  0.13        34.96  218.45
# 25      away      63.31       27.19   1.84   1.02  0.24       354.26  347.28
# 26      away      60.51       26.51   2.79   2.67  0.28       337.47    7.72
# 27      away      66.60       24.27   1.18   1.63  0.19       326.61    4.15
# 28      away      65.12        9.43   2.05   1.73  0.31         4.69  247.76
# 29      away      65.18       16.36   2.28   2.24  0.34       338.44  231.37
# ...      ...        ...         ...    ...    ...   ...          ...     ...
# 509732  home      80.62       23.88   0.46   0.33  0.04       108.28  127.18
# 509733  home      84.09       25.66   1.72   0.55  0.17        30.21  359.17
# 509734  home      84.23        7.77   2.26   0.36  0.22        73.19  102.30
# 509735  home      84.96       24.77   2.79   1.13  0.29        71.79   19.98
# 509736  home      84.90       23.78   3.74   0.84  0.38        44.13   15.99
# 509737  home      84.19       26.77   1.75   0.85  0.20       110.27    9.23
# 509738  home      84.36       42.29   1.56   1.58  0.15        93.31   89.70
# 509739  home      81.19       23.75   4.23   2.43  0.41        66.34   41.24
# 509740  away      86.64       28.20   0.21   0.89  0.04       234.21   82.18
# 509741  away      90.09       42.83   3.11   2.47  0.31       175.02  130.60
# 509742  away      88.22       28.05   1.08   2.78  0.11       242.66  114.87
# 509743  away      85.82       30.07   1.29   1.35  0.11       205.86  247.08
# 509744  away      87.48       23.67   1.13   1.88  0.11       311.08   16.33
# 509745  away      99.14       29.81   1.97   1.40  0.19       256.20  248.21
# 509746  away      87.86       27.40   1.35   2.17  0.12       222.14   76.87
# 509747  away      87.43       27.78   2.43   1.85  0.25       242.40   13.99
# 509748  away      85.86       24.68   1.93   0.88  0.21       247.92  316.90
# 509749  away      87.82       21.82   2.90   2.67  0.29       295.36   40.07
# 509750  away      87.91       22.38   4.52   2.55  0.44       338.09  306.72
# 509751  home      85.12       29.18   0.96   1.04  0.10        81.51  221.23
# 509752  home      86.76       22.02   2.58   0.74  0.26        65.37   41.26
# 509753  home      81.82       26.99   3.08   1.43  0.32       213.67  266.73
# 509754  home      87.34       41.37   3.96   1.48  0.39       139.94  136.00
# 509755  home      86.00       27.50   0.06   0.72  0.02        42.87   86.49
# 509756  home      85.68       24.31   1.04   0.35  0.10        43.66  326.53
# 509757  home      86.77       24.20   2.14   2.12  0.22        44.55   15.31
# 509758  home      86.76       27.18   1.16   0.66  0.11        53.63   42.80
# 509759  home      87.26       27.05   2.59   1.18  0.26         3.96   21.12
# 509760  home      84.57       24.37   4.36   1.79  0.47       148.08  183.34
# 509761  home      80.80       26.35   4.87   4.10  0.45       135.44  118.24
#
#               DisplayName  Season  ...  StadiumType        Turf  GameWeather  \
# 0              Eric Berry    2017  ...      Outdoor  Artificial        Clear
# 1            Allen Bailey    2017  ...      Outdoor  Artificial        Clear
# 2          Justin Houston    2017  ...      Outdoor  Artificial        Clear
# 3         Derrick Johnson    2017  ...      Outdoor  Artificial        Clear
# 4              Ron Parker    2017  ...      Outdoor  Artificial        Clear
# 5                Dee Ford    2017  ...      Outdoor  Artificial        Clear
# 6       Terrance Mitchell    2017  ...      Outdoor  Artificial        Clear
# 7          Phillip Gaines    2017  ...      Outdoor  Artificial        Clear
# 8         Daniel Sorensen    2017  ...      Outdoor  Artificial        Clear
# 9           Marcus Peters    2017  ...      Outdoor  Artificial        Clear
# 10            Chris Jones    2017  ...      Outdoor  Artificial        Clear
# 11         Danny Amendola    2017  ...      Outdoor  Artificial        Clear
# 12         Rob Gronkowski    2017  ...      Outdoor  Artificial        Clear
# 13          Marcus Cannon    2017  ...      Outdoor  Artificial        Clear
# 14            Nate Solder    2017  ...      Outdoor  Artificial        Clear
# 15              Tom Brady    2017  ...      Outdoor  Artificial        Clear
# 16            Chris Hogan    2017  ...      Outdoor  Artificial        Clear
# 17          Brandin Cooks    2017  ...      Outdoor  Artificial        Clear
# 18            James White    2017  ...      Outdoor  Artificial        Clear
# 19             Shaq Mason    2017  ...      Outdoor  Artificial        Clear
# 20          David Andrews    2017  ...      Outdoor  Artificial        Clear
# 21             Joe Thuney    2017  ...      Outdoor  Artificial        Clear
# 22             Eric Berry    2017  ...      Outdoor  Artificial        Clear
# 23           Allen Bailey    2017  ...      Outdoor  Artificial        Clear
# 24         Justin Houston    2017  ...      Outdoor  Artificial        Clear
# 25        Derrick Johnson    2017  ...      Outdoor  Artificial        Clear
# 26             Ron Parker    2017  ...      Outdoor  Artificial        Clear
# 27               Dee Ford    2017  ...      Outdoor  Artificial        Clear
# 28      Terrance Mitchell    2017  ...      Outdoor  Artificial        Clear
# 29         Phillip Gaines    2017  ...      Outdoor  Artificial        Clear
# ...                   ...     ...  ...          ...         ...          ...
# 509732     Russell Wilson    2018  ...      Outdoor  Artificial       Cloudy
# 509733       Justin Britt    2018  ...      Outdoor  Artificial       Cloudy
# 509734      Tyler Lockett    2018  ...      Outdoor  Artificial       Cloudy
# 509735      Germain Ifedi    2018  ...      Outdoor  Artificial       Cloudy
# 509736        George Fant    2018  ...      Outdoor  Artificial       Cloudy
# 509737        Ethan Pocic    2018  ...      Outdoor  Artificial       Cloudy
# 509738        David Moore    2018  ...      Outdoor  Artificial       Cloudy
# 509739       Chris Carson    2018  ...      Outdoor  Artificial       Cloudy
# 509740       Corey Peters    2018  ...      Outdoor  Artificial       Cloudy
# 509741   Patrick Peterson    2018  ...      Outdoor  Artificial       Cloudy
# 509742     Antoine Bethea    2018  ...      Outdoor  Artificial       Cloudy
# 509743     Chandler Jones    2018  ...      Outdoor  Artificial       Cloudy
# 509744      Gerald Hodges    2018  ...      Outdoor  Artificial       Cloudy
# 509745      David Amerson    2018  ...      Outdoor  Artificial       Cloudy
# 509746     Deone Bucannon    2018  ...      Outdoor  Artificial       Cloudy
# 509747  Vincent Valentine    2018  ...      Outdoor  Artificial       Cloudy
# 509748    Vontarrius Dora    2018  ...      Outdoor  Artificial       Cloudy
# 509749     Haason Reddick    2018  ...      Outdoor  Artificial       Cloudy
# 509750        Budda Baker    2018  ...      Outdoor  Artificial       Cloudy
# 509751        Duane Brown    2018  ...      Outdoor  Artificial       Cloudy
# 509752         Ed Dickson    2018  ...      Outdoor  Artificial       Cloudy
# 509753     Russell Wilson    2018  ...      Outdoor  Artificial       Cloudy
# 509754        Jaron Brown    2018  ...      Outdoor  Artificial       Cloudy
# 509755       Justin Britt    2018  ...      Outdoor  Artificial       Cloudy
# 509756          Joey Hunt    2018  ...      Outdoor  Artificial       Cloudy
# 509757       Nick Vannett    2018  ...      Outdoor  Artificial       Cloudy
# 509758      Germain Ifedi    2018  ...      Outdoor  Artificial       Cloudy
# 509759        George Fant    2018  ...      Outdoor  Artificial       Cloudy
# 509760        Ethan Pocic    2018  ...      Outdoor  Artificial       Cloudy
# 509761       Chris Carson    2018  ...      Outdoor  Artificial       Cloudy
#
#        Temperature  Humidity  WindSpeed WindDirection  TeamAbbr  OppTeamAbbr  \
# 0             63.0      77.0        8.0            sw        KC           NE
# 1             63.0      77.0        8.0            sw        KC           NE
# 2             63.0      77.0        8.0            sw        KC           NE
# 3             63.0      77.0        8.0            sw        KC           NE
# 4             63.0      77.0        8.0            sw        KC           NE
# 5             63.0      77.0        8.0            sw        KC           NE
# 6             63.0      77.0        8.0            sw        KC           NE
# 7             63.0      77.0        8.0            sw        KC           NE
# 8             63.0      77.0        8.0            sw        KC           NE
# 9             63.0      77.0        8.0            sw        KC           NE
# 10            63.0      77.0        8.0            sw        KC           NE
# 11            63.0      77.0        8.0            sw        NE           KC
# 12            63.0      77.0        8.0            sw        NE           KC
# 13            63.0      77.0        8.0            sw        NE           KC
# 14            63.0      77.0        8.0            sw        NE           KC
# 15            63.0      77.0        8.0            sw        NE           KC
# 16            63.0      77.0        8.0            sw        NE           KC
# 17            63.0      77.0        8.0            sw        NE           KC
# 18            63.0      77.0        8.0            sw        NE           KC
# 19            63.0      77.0        8.0            sw        NE           KC
# 20            63.0      77.0        8.0            sw        NE           KC
# 21            63.0      77.0        8.0            sw        NE           KC
# 22            63.0      77.0        8.0            sw        KC           NE
# 23            63.0      77.0        8.0            sw        KC           NE
# 24            63.0      77.0        8.0            sw        KC           NE
# 25            63.0      77.0        8.0            sw        KC           NE
# 26            63.0      77.0        8.0            sw        KC           NE
# 27            63.0      77.0        8.0            sw        KC           NE
# 28            63.0      77.0        8.0            sw        KC           NE
# 29            63.0      77.0        8.0            sw        KC           NE
# ...            ...       ...        ...           ...       ...          ...
# 509732        45.0      76.0        5.0            se       SEA          ARI
# 509733        45.0      76.0        5.0            se       SEA          ARI
# 509734        45.0      76.0        5.0            se       SEA          ARI
# 509735        45.0      76.0        5.0            se       SEA          ARI
# 509736        45.0      76.0        5.0            se       SEA          ARI
# 509737        45.0      76.0        5.0            se       SEA          ARI
# 509738        45.0      76.0        5.0            se       SEA          ARI
# 509739        45.0      76.0        5.0            se       SEA          ARI
# 509740        45.0      76.0        5.0            se       ARI          SEA
# 509741        45.0      76.0        5.0            se       ARI          SEA
# 509742        45.0      76.0        5.0            se       ARI          SEA
# 509743        45.0      76.0        5.0            se       ARI          SEA
# 509744        45.0      76.0        5.0            se       ARI          SEA
# 509745        45.0      76.0        5.0            se       ARI          SEA
# 509746        45.0      76.0        5.0            se       ARI          SEA
# 509747        45.0      76.0        5.0            se       ARI          SEA
# 509748        45.0      76.0        5.0            se       ARI          SEA
# 509749        45.0      76.0        5.0            se       ARI          SEA
# 509750        45.0      76.0        5.0            se       ARI          SEA
# 509751        45.0      76.0        5.0            se       SEA          ARI
# 509752        45.0      76.0        5.0            se       SEA          ARI
# 509753        45.0      76.0        5.0            se       SEA          ARI
# 509754        45.0      76.0        5.0            se       SEA          ARI
# 509755        45.0      76.0        5.0            se       SEA          ARI
# 509756        45.0      76.0        5.0            se       SEA          ARI
# 509757        45.0      76.0        5.0            se       SEA          ARI
# 509758        45.0      76.0        5.0            se       SEA          ARI
# 509759        45.0      76.0        5.0            se       SEA          ARI
# 509760        45.0      76.0        5.0            se       SEA          ARI
# 509761        45.0      76.0        5.0            se       SEA          ARI
#
#        Yard_class
# 0             > 6
# 1             > 6
# 2             > 6
# 3             > 6
# 4             > 6
# 5             > 6
# 6             > 6
# 7             > 6
# 8             > 6
# 9             > 6
# 10            > 6
# 11            > 6
# 12            > 6
# 13            > 6
# 14            > 6
# 15            > 6
# 16            > 6
# 17            > 6
# 18            > 6
# 19            > 6
# 20            > 6
# 21            > 6
# 22            2-3
# 23            2-3
# 24            2-3
# 25            2-3
# 26            2-3
# 27            2-3
# 28            2-3
# 29            2-3
# ...           ...
# 509732        2-3
# 509733        2-3
# 509734        2-3
# 509735        2-3
# 509736        2-3
# 509737        2-3
# 509738        2-3
# 509739        2-3
# 509740        > 6
# 509741        > 6
# 509742        > 6
# 509743        > 6
# 509744        > 6
# 509745        > 6
# 509746        > 6
# 509747        > 6
# 509748        > 6
# 509749        > 6
# 509750        > 6
# 509751        > 6
# 509752        > 6
# 509753        > 6
# 509754        > 6
# 509755        > 6
# 509756        > 6
# 509757        > 6
# 509758        > 6
# 509759        > 6
# 509760        > 6
# 509761        > 6
#
# [509762 rows x 38 columns]

# %%
nfl['Defenders_vs_Distance'] = nfl['DefendersInTheBox'] / nfl['Distance']

# %%
classes = {'< 0': 1,
           '0-1': 2,
           '2-3': 3,
           '4-6': 4,
           '> 6': 5}

nfl['Yard_class'] = nfl['Yard_class'].apply(lambda x: classes[x])

# %% [markdown]
# ## Random Forest

# %%
X = nfl.drop('Yard_class', axis=1)
y = nfl['Yard_class']

for col in X.columns:
    le = LabelEncoder()
    le.fit(list(X[col].astype(str).values))
    X[col] = le.transform(list(X[col].astype(str).values))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    stratify=y,
                                                    random_state=220)

# %%
param_rf = {'n_estimators': [120, 300, 500, 800, 1200],
            'max_depth': [None, 5, 8, 15, 25, 30],
            'min_samples_split': [2, 5, 10, 15, 100],
            'min_samples_leaf': [1, 2, 5, 10],
            'max_features': [None, 'log2', 'sqrt']}

rs_rf = run_randomized_search(RandomForestClassifier, 'rfc',
                              param_rf, X_train, X_test,
                              y_train, y_test, random_state=220)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.

# %%
rfc = pickle.load(open('Models/rfc.sav', 'rb'))

plot_feat_imp(rfc, X_train);

# %% [markdown]
# ## Catboost

# %%
X = nfl.drop('Yard_class', axis=1)
y = nfl['Yard_class']

# %%
cat_feats = []
for col in X.columns:
    if X[col].dtype == 'O':
        cat_feats.append(col)

# %%
param_cb = {'learning_rate': [0.01, 0.015, 0.025, 0.05, 0.1],
            'depth': [3, 5, 7, 9, 12, 15, 17, 25],
            'l2_leaf_reg': [1, 3, 5, 10, 100]}

rs_cb = run_randomized_search(cb.CatBoostClassifier, 'cbc'
                              param_cb, X_train, X_test,
                              y_train, y_test, random_state=220)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.

# %%
cbc = pickle.load(open('Models/cbc.sav', 'rb'))

plot_feat_imp(cbc, X_train);

# %% [markdown]
# ## Logistic Regression

# %%
X = nfl.drop('Yard_class', axis=1)
y = nfl['Yard_class']

X = pd.get_dummies(X, drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    stratify=y,
                                                    random_state=220)

# %%
scaler = StandardScaler()

X_train_scale = X_train.copy()
X_test_scale = X_test.copy()

int_cols = []
for cols in nfl.columns:
    if (nfl[cols].dtype != 'O') & (cols != 'Yard_class'):
        int_cols.append(cols)

scale_feats_train = X_train_scale[int_cols]
scale_feats_test = X_test_scale[int_cols]
scale_feats_train = scaler.fit_transform(scale_feats_train.values)
scale_feats_test = scaler.transform(scale_feats_test.values)

X_train_scale[int_cols] = scale_feats_train
X_test_scale[int_cols] = scale_feats_test

# %%
param_log = {'C': np.geomspace(0.001, 100, num=6),
             'penalty': ['l1', 'l2']}

rs_log = run_randomized_search_scaled(LogisticRegression, 'log',
                                      param_log, X_train_scale,
                                      X_test_scale, y_train, y_test)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#
# ~/anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     426
# --> 427             self._condition.wait(timeout)
#     428
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-3b78f89c9bbf> in <module>
#       4 rs_log = run_randomized_search_scaled(LogisticRegression, 'log',
#       5                                       param_log, X_train_scale,
# ----> 6                                       X_test_scale, y_train, y_test)
#       7
#       8 log = pickle.load(open('Models/log.sav', 'rb'))
#
# ~/Documents/fis/Projects/NFL_yards_gained/modeling.py in run_randomized_search_scaled(model, model_name, params, X_train_scale, X_test_scale, y_train, y_test, random_state)
#      92                                               decision_function_shape='ovo',
#      93                                               random_state=random_state),
# ---> 94                                 param_distributions=params,
#      95                                 scoring='accuracy',
#      96                                 cv=5, verbose=1, n_jobs=-1)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1467         evaluate_candidates(ParameterSampler(
#    1468             self.param_distributions, self.n_iter,
# -> 1469             random_state=self.random_state))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     665                                for parameters, (train, test)
#     666                                in product(candidate_params,
# --> 667                                           cv.split(X, y, groups)))
#     668
#     669                 if len(out) < 1:
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     853                     # scheduling.
#     854                     ensure_ready = self._managed_backend
# --> 855                     backend.abort_everything(ensure_ready=ensure_ready)
#     856
#     857                 if isinstance(exception, TransportableException):
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in abort_everything(self, ensure_ready)
#     536         """Shutdown the workers and restart a new one with the same parameters
#     537         """
# --> 538         self._workers.shutdown(kill_workers=True)
#     539         delete_folder(self._workers._temp_folder)
#     540         self._workers = None
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py in shutdown(self, wait, kill_workers)
#    1094                     pass
#    1095             if wait:
# -> 1096                 qmt.join()
#    1097
#    1098         cq = self._call_queue
#
# ~/anaconda3/lib/python3.7/threading.py in join(self, timeout)
#    1030
#    1031         if timeout is None:
# -> 1032             self._wait_for_tstate_lock()
#    1033         else:
#    1034             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1046         if lock is None:  # already determined that the C code is done
#    1047             assert self._is_stopped
# -> 1048         elif lock.acquire(block, timeout):
#    1049             lock.release()
#    1050             self._stop()
#
# KeyboardInterrupt:

# %%
log = pickle.load(open('Models/log.sav', 'rb'))

plot_feat_imp(log, X_train);

# %% [markdown]
# ## K-Neighbors Classifier (KNN)

# %%
param_knn = {'n_neighbors': [2, 8, 32]}

rs_knn = run_randomized_search_scaled(KNeighborsClassifier, 'knn',
                                      param_knn, X_train_scale,
                                      X_test_scale, y_train, y_test)

knn = pickle.load(open('Models/knn.sav', 'rb'))
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.

# %% [markdown]
# ## Support Vector Machine (SVM)

# %%
param_svm = {'C': np.geomspace(0.001, 1000, num=7)}

rs_svm = run_randomized_search(SVC, param_svm,
                               X_train_scale, X_test_scale,
                               y_train, y_test, random_state=220)

# %%
svm = pickle.load(open('Models/svc.sav', 'rb'))

plot_feat_imp(svm, X_train);
